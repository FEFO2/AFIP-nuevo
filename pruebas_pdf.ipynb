# %%
from pypdf import PdfReader

# %%
reader = PdfReader("30714894346_001_00002_00003564.pdf")

# %%
for page in reader.pages:
    texto = page.extract_text()
    print(texto)
# Out:
# Fecha de Emisión:
# ORIGINAL
# ARANCIA SERVICES S.R.L.
# Saenz Peña R. Pte. Av. 720 Piso:4 Dpto:C -
# Ciudad de Buenos Aires
# Período Facturado Desde: Hasta: Fecha de Vto. para el pago:
# CUIT:
# Condición de venta:
# Condición frente al IVA:
# Apellido y Nombre / Razón Social:
# Domicilio Comercial:
# 01/04/2026 01/04/2026 01/04/2026
# 01/04/2026
# 30714894346
# 30615265450 NEW PGA S. R. L.
# Exruta Nac 7 Km 0,700 0 - Villa Mercedes, San Luis
# Tarjeta de Crédito
# CUIT:
# Ingresos Brutos:
# Fecha de Inicio de Actividades:
# Punto de Venta: Comp. Nro:00002 00003564
# Domicilio Comercial:
# Razón Social:
# ARANCIA TRAVEL
# Condición frente al IVA:
# FACTURAACOD. 01
# IVA Responsable Inscripto
# IVA Responsable Inscripto
# 01/12/2016
# 30714894346
# Código Producto / Servicio Cantidad U. medida Precio Unit. % Bonif Subtotal Alicuota
# IVA Subtotal c/IVA
# CECO 1285    INTERMEDIACION POR
# EMISION DE PASAJE AEREO
# AEPRESPSSAEP PASAJERO  SMOCOVICH
# CATALINA  MAFFE JUAN IGNACIO
# ...
